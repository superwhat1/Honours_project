# %%
import pandas as pd
import numpy as np

# %%
WT_63 = pd.read_csv('WT_SC_63_E9_ARSDA.csv')
WT_64 = pd.read_csv('WT_SC_64_E9_ARSDA.csv')
DTT_65= pd.read_csv('DTT_SC_65_E9_ARSDA.csv')
DTT_66= pd.read_csv('DTT_SC_66_E9_ARSDA.csv')
TM_67 = pd.read_csv('TM_SC_67_E9_ARSDA.csv')
TM_68 = pd.read_csv('TM_SC_68_E9_ARSDA.csv')

# %%
CTRL_51 = pd.read_csv('CTRL_SC_51_E5_ARSDA.csv')
CTRL_52 = pd.read_csv('CTRL_SC_52_E5_ARSDA.csv')
DTT_53= pd.read_csv('DTT_SC_53_E5_ARSDA.csv')
DTT_54= pd.read_csv('DTT_SC_54_E5_ARSDA.csv')
TM_55 = pd.read_csv('TM_SC_55_E5_ARSDA.csv')
TM_56 = pd.read_csv('TM_SC_56_E5_ARSDA.csv')

# %%
apop_gene_list = pd.read_csv('apop_gene_list.csv')

# %%
apop_gene_list
# Out:
#    gene_id gene_name                gene_alias system_name  uniprot  \
# 0       A1      AIF1                      CPD1     YNR074C   P52923
# 1       A2      BIR1                       NaN     YJR089W   P47134
# 2       A3      CPR3                      CYP3     YML078W   P25719
# 3       A4      DRE2                       NaN     YKR071C   P36152
# 4       A5      ESP1                       NaN     YGR098C   Q03018
# 5       A6      FIS1                      MDV2     YIL065C   P40515
# 6       A7      MCA1                      YCA1     YOR197W   Q08601
# 7       A8      MCD1         PDS3| RHC21| SCC1     YDL003W   Q12158
# 8       A9    NMA111                      YNM3     YNL123W   P53920
# 9      A10      NUC1                       NaN     YJL208C   P08466
# 10     A11      OYE2                       NaN     YHR179W   Q03558
# 11     A12      OYE3                      ZRG6     YPL171C   P41816
# 12     A13      PET9                AAC2| ANC2     YBL030C   P18239
# ...

# %%
apop_genes = pd.DataFrame({'Gene':apop_gene_list['system_name']})

# %%
match_apop_genes_63 = apop_genes.merge(WT_63, on='Gene')
match_apop_genes_64 = apop_genes.merge(WT_64, on='Gene')
match_apop_genes_65 = apop_genes.merge(DTT_65, on='Gene')
match_apop_genes_66 = apop_genes.merge(DTT_66, on='Gene')
match_apop_genes_67 = apop_genes.merge(TM_67, on='Gene')
match_apop_genes_68 = apop_genes.merge(TM_68, on='Gene')

# %%
match_apop_genes_51 = apop_genes.merge(CTRL_51, on='Gene')
match_apop_genes_52 = apop_genes.merge(CTRL_52, on='Gene')
match_apop_genes_53 = apop_genes.merge(DTT_53, on='Gene')
match_apop_genes_54 = apop_genes.merge(DTT_54, on='Gene')
match_apop_genes_55 = apop_genes.merge(TM_55, on='Gene')
match_apop_genes_56 = apop_genes.merge(TM_56, on='Gene')

# %%
match_apop_genes_63.to_csv('match_apop_genes_63.csv')
match_apop_genes_64.to_csv('match_apop_genes_64.csv')
match_apop_genes_65.to_csv('match_apop_genes_65.csv')
match_apop_genes_66.to_csv('match_apop_genes_66.csv')
match_apop_genes_67.to_csv('match_apop_genes_67.csv')
match_apop_genes_68.to_csv('match_apop_genes_68.csv')

# %%
match_apop_genes_51.to_csv('match_apop_genes_51.csv')
match_apop_genes_52.to_csv('match_apop_genes_52.csv')
match_apop_genes_53.to_csv('match_apop_genes_53.csv')
match_apop_genes_54.to_csv('match_apop_genes_54.csv')
match_apop_genes_55.to_csv('match_apop_genes_55.csv')
match_apop_genes_56.to_csv('match_apop_genes_56.csv')

# %%
sc_excluding_apop_51 = pd.merge(CTRL_51,apop_genes, indicator=True, how='outer').query('_merge=="left_only"').drop('_merge', axis=1)
sc_excluding_apop_52 = pd.merge(CTRL_52,apop_genes, indicator=True, how='outer').query('_merge=="left_only"').drop('_merge', axis=1)
sc_excluding_apop_53 = pd.merge(DTT_53,apop_genes, indicator=True, how='outer').query('_merge=="left_only"').drop('_merge', axis=1)
sc_excluding_apop_54 = pd.merge(DTT_54,apop_genes, indicator=True, how='outer').query('_merge=="left_only"').drop('_merge', axis=1)
sc_excluding_apop_55 = pd.merge(TM_55,apop_genes, indicator=True, how='outer').query('_merge=="left_only"').drop('_merge', axis=1)
sc_excluding_apop_56 = pd.merge(TM_56,apop_genes, indicator=True, how='outer').query('_merge=="left_only"').drop('_merge', axis=1)
sc_excluding_apop_63 = pd.merge(WT_63,apop_genes, indicator=True, how='outer').query('_merge=="left_only"').drop('_merge', axis=1)
sc_excluding_apop_64 = pd.merge(WT_64,apop_genes, indicator=True, how='outer').query('_merge=="left_only"').drop('_merge', axis=1)
sc_excluding_apop_65 = pd.merge(DTT_65,apop_genes, indicator=True, how='outer').query('_merge=="left_only"').drop('_merge', axis=1)
sc_excluding_apop_66 = pd.merge(DTT_65,apop_genes, indicator=True, how='outer').query('_merge=="left_only"').drop('_merge', axis=1)
sc_excluding_apop_67 = pd.merge(TM_67,apop_genes, indicator=True, how='outer').query('_merge=="left_only"').drop('_merge', axis=1)
sc_excluding_apop_68 = pd.merge(TM_68,apop_genes, indicator=True, how='outer').query('_merge=="left_only"').drop('_merge', axis=1)

# %%
sc_excluding_apop_51.to_csv('sc_excluding_apop_51.csv')
sc_excluding_apop_52.to_csv('sc_excluding_apop_52.csv')
sc_excluding_apop_53.to_csv('sc_excluding_apop_53.csv')
sc_excluding_apop_54.to_csv('sc_excluding_apop_54.csv')
sc_excluding_apop_55.to_csv('sc_excluding_apop_55.csv')
sc_excluding_apop_56.to_csv('sc_excluding_apop_56.csv')
sc_excluding_apop_63.to_csv('sc_excluding_apop_63.csv')
sc_excluding_apop_64.to_csv('sc_excluding_apop_64.csv')
sc_excluding_apop_65.to_csv('sc_excluding_apop_65.csv')
sc_excluding_apop_66.to_csv('sc_excluding_apop_66.csv')
sc_excluding_apop_67.to_csv('sc_excluding_apop_67.csv')
sc_excluding_apop_68.to_csv('sc_excluding_apop_68.csv')
